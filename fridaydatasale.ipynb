# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('fridaydatasales.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 550063    False       False   False  False       False          False
# 550064    False       False   False  False       False          False
# 550065    False       False   False  False       False          False
# 550066    False       False   False  False       False          False
# 550067    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 545902  1006039  P00064042      F  46-50           0             B
# 545904  1006040  P00081142      M  26-35           6             B
# 545907  1006040  P00277642      M  26-35           6             B
# 545908  1006040  P00127642      M  26-35           6             B
# 545914  1006040  P00217442      M  26-35           6             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1])

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19])

# %%
df['Purchase'].sum()
# Out:
# 5095812742

# %%
df['Purchase'].mean()
# Out:
# 9263.968712959126

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9263.968712959126

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
for i in df.columns:
    print(i , df[i].nunique())
# Out:
# User_ID 5891
# Product_ID 3631
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 20
# Purchase 18105

# %% [markdown]
# ANALYSING GENDER

# %%
for i in df.columns:
    print(df[i].nunique() ,':',i)
# Out:
# 5891 : User_ID
# 3631 : Product_ID
# 2 : Gender
# 7 : Age
# 21 : Occupation
# 3 : City_Category
# 5 : Stay_In_Current_City_Years
# 2 : Marital_Status
# 20 : Product_Category_1
# 18105 : Purchase

# %%
data=pd.DataFrame({'Ratio':[len(df[df['Gender']=='M']),len(df[df['Gender']=='F']) ]}, index = ['Male','Female'])
data.plot.pie( y='Ratio',figsize=(6,6),autopct='%.1f')
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind='pie', autopct='%.2f',title='Gender ratio',figsize=(6,6))
# Out:
# <Axes: title={'center': 'Gender ratio'}>

# %%
df.groupby('Gender').size().plot(kind='bar',figsize=(7,7),title='Gender ration')
# Out:
# <Axes: title={'center': 'Gender ration'}, xlabel='Gender'>

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    135809
# M    414259
# dtype: int64

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct='%.2f',title='GENDER  PURCHASE RATIO')
# Out:
# /tmp/ipykernel_335/1603132279.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct='%.2f',title='GENDER  PURCHASE RATIO')
# <Axes: title={'center': 'GENDER  PURCHASE RATIO'}, ylabel='Purchase'>

# %%
df.groupby('Gender').mean()['Purchase'].plot(kind='pie',autopct="%.3f")
# Out:
# /tmp/ipykernel_335/2886125473.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()['Purchase'].plot(kind='pie',autopct="%.3f")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ANALYSE AGE AND MARITAL STATUS

# %%
df.groupby('Age').size().plot(kind='bar',title='Purchase distribution by age',figsize=(7,7))
# Out:
# <Axes: title={'center': 'Purchase distribution by age'}, xlabel='Age'>

# %%
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])
    
data=pd.DataFrame(lst,columns=['Age','Product_ID'])

# %%
data.plot.bar( x='Age',figsize=(6,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].sort_values().plot(kind='bar',figsize=(12,6),title='amount spend by age')
# Out:
# /tmp/ipykernel_335/3440050996.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].sort_values().plot(kind='bar',figsize=(12,6),title='amount spend by age')
# <Axes: title={'center': 'amount spend by age'}, xlabel='Age'>

# %%
df.groupby("Age").mean()['Purchase'].sort_values().plot(kind='bar',figsize=(12,6),title='amount spend by age')
# Out:
# /tmp/ipykernel_335/177953556.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Age").mean()['Purchase'].sort_values().plot(kind='bar',figsize=(12,6),title='amount spend by age')
# <Axes: title={'center': 'amount spend by age'}, xlabel='Age'>

# %%
df.groupby("Age").sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# /tmp/ipykernel_335/881164559.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Age").sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# /tmp/ipykernel_335/1984055404.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase'].plot(kind='pie',autopct='%.2f')
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind="pie",autopct="%.2f",title="marital status")
# Out:
# <Axes: title={'center': 'marital status'}>

# %%
df.groupby("Gender").size().plot(kind="pie",autopct="%.2f",title="gender percentage in friday sale")
# Out:
# <Axes: title={'center': 'gender percentage in friday sale'}>

# %% [markdown]
# MUTICOLUMN ANALYSIS

# %%
df.groupby("Age").size().plot(kind="bar",figsize=(6,6),title="purchase distribution by age")
# Out:
# <Axes: title={'center': 'purchase distribution by age'}, xlabel='Age'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x="Gender",hue="Age",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Marital_Status',hue='Age',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Marital_Status',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='City_Category',hue='Gender',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Age',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Marital_Status",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby("City_Category").size().plot(kind="pie",figsize=(7,8),autopct='%.2f',title="% of city category")
# Out:
# <Axes: title={'center': '% of city category'}>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# /tmp/ipykernel_335/1359040361.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# /tmp/ipykernel_335/3404751240.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct='%.2f')
# <Axes: ylabel='Purchase'>

# %% [markdown]
# OCCUPATION AND PRODUCT ANALYSIS

# %%
sns.countplot(x=df["Stay_In_Current_City_Years"])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").size().plot(kind="pie",autopct="%.3f")
# Out:
# <Axes: >

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Age',data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar')
# Out:
# /tmp/ipykernel_335/2549684239.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar')
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind = 'bar')
# Out:
# /tmp/ipykernel_335/1632985777.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind = 'bar')
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# /tmp/ipykernel_335/2195280667.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").mean()['Purchase'].sort_values().plot(kind='bar')
# Out:
# /tmp/ipykernel_335/877687425.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Occupation").mean()['Purchase'].sort_values().plot(kind='bar')
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind='bar')
# Out:
# /tmp/ipykernel_335/594745959.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind='bar')
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# /tmp/ipykernel_335/3011761601.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind = 'bar')
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# /tmp/ipykernel_335/1632911214.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').mean()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# /tmp/ipykernel_335/485863399.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_ID').mean()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
COMBINIG AGE AND MARITAL STATUS

# %%
lst=[]
for i in range(len(df)):
    lst.append(df['Gender'][i]+"_"+str(df["Marital_Status"][i]))
    
df['MaritalGender']=lst

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
sns.countplot(x=df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x='Age',hue='MaritalGender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = df['Product_Category_1'], hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'], hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'], hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# CONCLUSION: we have analyzed that men_unmarried spending the most in Black Friday Sales, then comes men_married ,then comes female_unmarried then comes female_married .So this will help us to promote our products and same manner.So we are going to spend most amount in our promotion to the male candidates those who are unmarried.
